# %%
import matplotlib.pyplot as plt
import scipy.integrate as integrate
import math
import numpy as np
import pandas as pd

# %% [markdown]
# ## Defining variables to be used in equation

# %%
A = 424.5
B = 12.5
T = 5.05
L = 20 *(10**-7)
a = 3.2509*(10**-8)
w = 437.6*(10**-7)
q = np.linspace(0 , 1 ,1000)

# %% [markdown]
# ## EQUATION

# %% [markdown]
# def func_z(w):
#     return integrate.quad(lambda q : (4 * math.pi * np.exp(q**2 * (L**2/4))) /( (w - (w*q))**2 + (T/2)**2),0,1)

# %% [markdown]
# print (func_z(w))

# %%
def func_z(q):
    return integrate.quad(lambda q : (4 * math.pi * np.exp(q**2 * (L**2/4))) /( (w - (w*q))**2 + (T/2)**2),0,1)

# %%
x = np.arange( 0,1,1000 )
y = np.arange( 0,1,1000 )

plt.plot( x, y, func_z(q) )
plt.ylabel( "y" )
plt.xlabel( "x" )
plt.show()
